# %%
setwd('/home/swagmaster/Documents/Tony\'s files/Updated_SCORE_code_+_README/Off-Spotter_remote_v1-1/analysed_guides_1q_4_5_19_fco_nofilt_noTAR/gRNAs')
library(data.table)
candguides = data.frame(fread("OffSpotter_summary.csv"))
#head(candguides)
#head(candguides[10])  #chr_loc_1
keep1 = candguides[10] > 147000000
#sum(keep1)
#head(candguides[11])
keep2 = candguides[11] < 148400000
#sum(keep2)
keepf = keep1 & keep2
#sum(keepf)
finito = candguides[keepf,]
finito
write.csv(finito, file = 'finito.csv')
# Out:
#      Sequence             X0.MM X1.MM X2.MM X3.MM  X4.MM  X5.MM  Total.MM
# 13   TTTAGATCCTGAAACCTCAC   3       7     2     15    188   2876   3092
# 35   AAATTAGGAGGAGGGGCCTT   2       3    64    524   1616   4267   6477
# 75   GTTTTCAGCTTCCTTGTGAT   5     173   580    847   1205   7439  10250
# 93   AAAGTGTTAAAATTAGGAGG   2       1     1     91    755   4655   5506
# 134  AGTGTTAAAATTAGGAGGAG   2       1     0     30    298   2609   2941
# 183  ATACAATTTTTTTTTTGAGA  10     114   822   4185  21949 149310 176391
# 194  TTTGGAGAAAGAGAAGACAC   3       1     5     73    611   4313   5007
# 208  GAGACGGGGTTTCGTCATAT   9     790 13234  85322 176567 125038 400961
# 295  AGGGGCAGCTCTTCAGAGAT   5       9    13     27    224   1651   1930
# 302  GGGGTTTCGTCATATTGGCC  29    1398 23093 123526 205440 199045 552532
# 343  GCCTTAGGGGCCACTTCGTT   2       1     1      8     47    450    510
# 361  TAGGAGGAGGGGCCTTTGGG   4     232   808   1638   2738   5597  11018
# ...
